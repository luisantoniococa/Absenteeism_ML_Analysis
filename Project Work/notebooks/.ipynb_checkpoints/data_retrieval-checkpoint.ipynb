# %%
# we import the relevant libraries
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
import pandas as pd
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker
# Allow us to declare column types
from sqlalchemy import Column, Integer, String, Float, MetaData, Table



#################################################
# Database Setup
#################################################

connection_string = "root:postgres@absenteeismdb.c8c5c5y5lwr1.us-east-1.rds.amazonaws.com:5432/employee_db"
engine = create_engine(f'postgresql://{connection_string}')

# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# %%
# download the data from the created S3 bucket
data = pd.read_csv('https://absenteeism-data-project.s3.amazonaws.com/Absenteeism_data.csv')

# %%
data
# Out:
#      ID  Reason for Absence        Date  Transportation Expense  \
# 0    11                  26  07/07/2015                     289
# 1    36                   0  14/07/2015                     118
# 2     3                  23  15/07/2015                     179
# 3     7                   7  16/07/2015                     279
# 4    11                  23  23/07/2015                     289
# ..   ..                 ...         ...                     ...
# 695  17                  10  23/05/2018                     179
# 696  28                   6  23/05/2018                     225
# 697  18                  10  24/05/2018                     330
# 698  25                  23  24/05/2018                     235
# 699  15                  28  31/05/2018                     291
#
#      Distance to Work  Age  Daily Work Load Average  Body Mass Index  \
# 0                  36   33                  239.554               30
# 1                  13   50                  239.554               31
# 2                  51   38                  239.554               31
# 3                   5   39                  239.554               24
# 4                  36   33                  239.554               30
# ..                ...  ...                      ...              ...
# 695                22   40                  237.656               22
# 696                26   28                  237.656               24
# 697                16   28                  237.656               25
# 698                16   32                  237.656               25
# 699                31   40                  237.656               25
#
#      Education  Children  Pets  Absenteeism Time in Hours
# 0            1         2     1                          4
# 1            1         1     0                          0
# 2            1         0     0                          2
# 3            1         2     0                          4
# 4            1         2     1                          2
# ..         ...       ...   ...                        ...
# 695          2         2     0                          8
# 696          1         1     2                          3
# 697          2         0     0                          8
# 698          3         0     0                          2
# 699          1         1     1                          2
#
# [700 rows x 12 columns]

# %%
# we create an initial base object
Base = declarative_base()

# %%
# we create a class based in the table we want to create
class employee(Base):
    __tablename__ = 'employees'
    id = Column(Integer, primary_key=True)
    reasonForAbsence = Column(Integer)
    date = Column(String(255))
    transportationExpense = Column(Integer)
    distanceToWork = Column(Integer)
    age = Column(Integer)
    workload= Column(Float)
    bodyMass= Column(Integer)
    education = Column(Integer)
    children = Column(Integer)
    pets = Column(Integer)
    absTime = Column(Float)

# %%
# we use the previous as a reference to create a database by the engine
meta = MetaData()

employees_tb = Table(
    'employees', meta,
    Column('id', Integer),
    Column('reasonForAbsence', Integer),
    Column('date', String(255)),
    Column('transportationExpense', Integer),
    Column('distanceToWork',Integer),
    Column('age', Integer),
    Column('workload',Float),
    Column('bodyMass',Integer),
    Column('education',Integer),
    Column('children', Integer),
    Column('pets', Integer),
    Column('absTime',Float),

)

# %%
meta.create_all(engine)

# %%
list_to_write = data.to_dict(orient='records')

# %%
list_to_write
# Out:
# [{'ID': 11,
#   'Reason for Absence': 26,
#   'Date': '07/07/2015',
#   'Transportation Expense': 289,
#   'Distance to Work': 36,
#   'Age': 33,
#   'Daily Work Load Average': 239.554,
#   'Body Mass Index': 30,
#   'Education': 1,
#   'Children': 2,
#   'Pets': 1,
#   'Absenteeism Time in Hours': 4},
#  {'ID': 36,
#   'Reason for Absence': 0,
#   'Date': '14/07/2015',
#   'Transportation Expense': 118,
#   'Distance to Work': 13,
#   'Age': 50,
#   'Daily Work Load Average': 239.554,
#   'Body Mass Index': 31,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 0},
#  {'ID': 3,
#   'Reason for Absence': 23,
#   'Date': '15/07/2015',
#   'Transportation Expense': 179,
#   'Distance to Work': 51,
#   'Age': 38,
#   'Daily Work Load Average': 239.554,
#   'Body Mass Index': 31,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 2},
#  {'ID': 7,
#   'Reason for Absence': 7,
#   'Date': '16/07/2015',
#   'Transportation Expense': 279,
#   'Distance to Work': 5,
#   'Age': 39,
#   'Daily Work Load Average': 239.554,
#   'Body Mass Index': 24,
#   'Education': 1,
#   'Children': 2,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 4},
#  {'ID': 11,
#   'Reason for Absence': 23,
#   'Date': '23/07/2015',
#   'Transportation Expense': 289,
#   'Distance to Work': 36,
#   'Age': 33,
#   'Daily Work Load Average': 239.554,
#   'Body Mass Index': 30,
#   'Education': 1,
#   'Children': 2,
#   'Pets': 1,
#   'Absenteeism Time in Hours': 2},
#  {'ID': 3,
#   'Reason for Absence': 23,
#   'Date': '10/07/2015',
#   'Transportation Expense': 179,
#   'Distance to Work': 51,
#   'Age': 38,
#   'Daily Work Load Average': 239.554,
#   'Body Mass Index': 31,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 2},
#  {'ID': 10,
#   'Reason for Absence': 22,
#   'Date': '17/07/2015',
#   'Transportation Expense': 361,
#   'Distance to Work': 52,
#   'Age': 28,
#   'Daily Work Load Average': 239.554,
#   'Body Mass Index': 27,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 4,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 20,
#   'Reason for Absence': 23,
#   'Date': '24/07/2015',
#   'Transportation Expense': 260,
#   'Distance to Work': 50,
#   'Age': 36,
#   'Daily Work Load Average': 239.554,
#   'Body Mass Index': 23,
#   'Education': 1,
#   'Children': 4,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 4},
#  {'ID': 14,
#   'Reason for Absence': 19,
#   'Date': '06/07/2015',
#   'Transportation Expense': 155,
#   'Distance to Work': 12,
#   'Age': 34,
#   'Daily Work Load Average': 239.554,
#   'Body Mass Index': 25,
#   'Education': 1,
#   'Children': 2,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 40},
#  {'ID': 1,
#   'Reason for Absence': 22,
#   'Date': '13/07/2015',
#   'Transportation Expense': 235,
#   'Distance to Work': 11,
#   'Age': 37,
#   'Daily Work Load Average': 239.554,
#   'Body Mass Index': 29,
#   'Education': 3,
#   'Children': 1,
#   'Pets': 1,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 20,
#   'Reason for Absence': 1,
#   'Date': '20/07/2015',
#   'Transportation Expense': 260,
#   'Distance to Work': 50,
#   'Age': 36,
#   'Daily Work Load Average': 239.554,
#   'Body Mass Index': 23,
#   'Education': 1,
#   'Children': 4,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 20,
#   'Reason for Absence': 1,
#   'Date': '14/07/2015',
#   'Transportation Expense': 260,
#   'Distance to Work': 50,
#   'Age': 36,
#   'Daily Work Load Average': 239.554,
#   'Body Mass Index': 23,
#   'Education': 1,
#   'Children': 4,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 20,
#   'Reason for Absence': 11,
#   'Date': '15/07/2015',
#   'Transportation Expense': 260,
#   'Distance to Work': 50,
#   'Age': 36,
#   'Daily Work Load Average': 239.554,
#   'Body Mass Index': 23,
#   'Education': 1,
#   'Children': 4,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 3,
#   'Reason for Absence': 11,
#   'Date': '15/07/2015',
#   'Transportation Expense': 179,
#   'Distance to Work': 51,
#   'Age': 38,
#   'Daily Work Load Average': 239.554,
#   'Body Mass Index': 31,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 1},
#  {'ID': 3,
#   'Reason for Absence': 23,
#   'Date': '15/07/2015',
#   'Transportation Expense': 179,
#   'Distance to Work': 51,
#   'Age': 38,
#   'Daily Work Load Average': 239.554,
#   'Body Mass Index': 31,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 4},
#  {'ID': 24,
#   'Reason for Absence': 14,
#   'Date': '17/07/2015',
#   'Transportation Expense': 246,
#   'Distance to Work': 25,
#   'Age': 41,
#   'Daily Work Load Average': 239.554,
#   'Body Mass Index': 23,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 3,
#   'Reason for Absence': 23,
#   'Date': '17/07/2015',
#   'Transportation Expense': 179,
#   'Distance to Work': 51,
#   'Age': 38,
#   'Daily Work Load Average': 239.554,
#   'Body Mass Index': 31,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 2},
#  {'ID': 3,
#   'Reason for Absence': 21,
#   'Date': '27/07/2015',
#   'Transportation Expense': 179,
#   'Distance to Work': 51,
#   'Age': 38,
#   'Daily Work Load Average': 239.554,
#   'Body Mass Index': 31,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 6,
#   'Reason for Absence': 11,
#   'Date': '30/07/2015',
#   'Transportation Expense': 189,
#   'Distance to Work': 29,
#   'Age': 33,
#   'Daily Work Load Average': 239.554,
#   'Body Mass Index': 25,
#   'Education': 1,
#   'Children': 2,
#   'Pets': 2,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 33,
#   'Reason for Absence': 23,
#   'Date': '05/08/2015',
#   'Transportation Expense': 248,
#   'Distance to Work': 25,
#   'Age': 47,
#   'Daily Work Load Average': 205.917,
#   'Body Mass Index': 32,
#   'Education': 1,
#   'Children': 2,
#   'Pets': 1,
#   'Absenteeism Time in Hours': 2},
#  {'ID': 18,
#   'Reason for Absence': 10,
#   'Date': '12/08/2015',
#   'Transportation Expense': 330,
#   'Distance to Work': 16,
#   'Age': 28,
#   'Daily Work Load Average': 205.917,
#   'Body Mass Index': 25,
#   'Education': 2,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 3,
#   'Reason for Absence': 11,
#   'Date': '03/08/2015',
#   'Transportation Expense': 179,
#   'Distance to Work': 51,
#   'Age': 38,
#   'Daily Work Load Average': 205.917,
#   'Body Mass Index': 31,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 1},
#  {'ID': 10,
#   'Reason for Absence': 13,
#   'Date': '10/08/2015',
#   'Transportation Expense': 361,
#   'Distance to Work': 52,
#   'Age': 28,
#   'Daily Work Load Average': 205.917,
#   'Body Mass Index': 27,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 4,
#   'Absenteeism Time in Hours': 40},
#  {'ID': 20,
#   'Reason for Absence': 28,
#   'Date': '14/08/2015',
#   'Transportation Expense': 260,
#   'Distance to Work': 50,
#   'Age': 36,
#   'Daily Work Load Average': 205.917,
#   'Body Mass Index': 23,
#   'Education': 1,
#   'Children': 4,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 4},
#  {'ID': 11,
#   'Reason for Absence': 18,
#   'Date': '17/08/2015',
#   'Transportation Expense': 289,
#   'Distance to Work': 36,
#   'Age': 33,
#   'Daily Work Load Average': 205.917,
#   'Body Mass Index': 30,
#   'Education': 1,
#   'Children': 2,
#   'Pets': 1,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 10,
#   'Reason for Absence': 25,
#   'Date': '24/08/2015',
#   'Transportation Expense': 361,
#   'Distance to Work': 52,
#   'Age': 28,
#   'Daily Work Load Average': 205.917,
#   'Body Mass Index': 27,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 4,
#   'Absenteeism Time in Hours': 7},
#  {'ID': 11,
#   'Reason for Absence': 23,
#   'Date': '04/08/2015',
#   'Transportation Expense': 289,
#   'Distance to Work': 36,
#   'Age': 33,
#   'Daily Work Load Average': 205.917,
#   'Body Mass Index': 30,
#   'Education': 1,
#   'Children': 2,
#   'Pets': 1,
#   'Absenteeism Time in Hours': 1},
#  {'ID': 30,
#   'Reason for Absence': 28,
#   'Date': '12/08/2015',
#   'Transportation Expense': 157,
#   'Distance to Work': 27,
#   'Age': 29,
#   'Daily Work Load Average': 205.917,
#   'Body Mass Index': 22,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 4},
#  {'ID': 11,
#   'Reason for Absence': 18,
#   'Date': '19/08/2015',
#   'Transportation Expense': 289,
#   'Distance to Work': 36,
#   'Age': 33,
#   'Daily Work Load Average': 205.917,
#   'Body Mass Index': 30,
#   'Education': 1,
#   'Children': 2,
#   'Pets': 1,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 3,
#   'Reason for Absence': 23,
#   'Date': '28/08/2015',
#   'Transportation Expense': 179,
#   'Distance to Work': 51,
#   'Age': 38,
#   'Daily Work Load Average': 205.917,
#   'Body Mass Index': 31,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 2},
#  {'ID': 3,
#   'Reason for Absence': 18,
#   'Date': '17/08/2015',
#   'Transportation Expense': 179,
#   'Distance to Work': 51,
#   'Age': 38,
#   'Daily Work Load Average': 205.917,
#   'Body Mass Index': 31,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 2,
#   'Reason for Absence': 18,
#   'Date': '27/08/2015',
#   'Transportation Expense': 235,
#   'Distance to Work': 29,
#   'Age': 48,
#   'Daily Work Load Average': 205.917,
#   'Body Mass Index': 33,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 5,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 1,
#   'Reason for Absence': 23,
#   'Date': '27/08/2015',
#   'Transportation Expense': 235,
#   'Distance to Work': 11,
#   'Age': 37,
#   'Daily Work Load Average': 205.917,
#   'Body Mass Index': 29,
#   'Education': 3,
#   'Children': 1,
#   'Pets': 1,
#   'Absenteeism Time in Hours': 4},
#  {'ID': 2,
#   'Reason for Absence': 18,
#   'Date': '17/08/2015',
#   'Transportation Expense': 235,
#   'Distance to Work': 29,
#   'Age': 48,
#   'Daily Work Load Average': 205.917,
#   'Body Mass Index': 33,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 5,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 3,
#   'Reason for Absence': 23,
#   'Date': '17/08/2015',
#   'Transportation Expense': 179,
#   'Distance to Work': 51,
#   'Age': 38,
#   'Daily Work Load Average': 205.917,
#   'Body Mass Index': 31,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 2},
#  {'ID': 10,
#   'Reason for Absence': 23,
#   'Date': '17/08/2015',
#   'Transportation Expense': 361,
#   'Distance to Work': 52,
#   'Age': 28,
#   'Daily Work Load Average': 205.917,
#   'Body Mass Index': 27,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 4,
#   'Absenteeism Time in Hours': 1},
#  {'ID': 11,
#   'Reason for Absence': 24,
#   'Date': '04/08/2015',
#   'Transportation Expense': 289,
#   'Distance to Work': 36,
#   'Age': 33,
#   'Daily Work Load Average': 205.917,
#   'Body Mass Index': 30,
#   'Education': 1,
#   'Children': 2,
#   'Pets': 1,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 19,
#   'Reason for Absence': 11,
#   'Date': '20/08/2015',
#   'Transportation Expense': 291,
#   'Distance to Work': 50,
#   'Age': 32,
#   'Daily Work Load Average': 205.917,
#   'Body Mass Index': 23,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 4},
#  {'ID': 2,
#   'Reason for Absence': 28,
#   'Date': '21/08/2015',
#   'Transportation Expense': 235,
#   'Distance to Work': 29,
#   'Age': 48,
#   'Daily Work Load Average': 205.917,
#   'Body Mass Index': 33,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 5,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 20,
#   'Reason for Absence': 23,
#   'Date': '28/08/2015',
#   'Transportation Expense': 260,
#   'Distance to Work': 50,
#   'Age': 36,
#   'Daily Work Load Average': 205.917,
#   'Body Mass Index': 23,
#   'Education': 1,
#   'Children': 4,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 4},
#  {'ID': 27,
#   'Reason for Absence': 23,
#   'Date': '01/09/2015',
#   'Transportation Expense': 184,
#   'Distance to Work': 42,
#   'Age': 27,
#   'Daily Work Load Average': 241.476,
#   'Body Mass Index': 21,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 2},
#  {'ID': 34,
#   'Reason for Absence': 23,
#   'Date': '07/09/2015',
#   'Transportation Expense': 118,
#   'Distance to Work': 10,
#   'Age': 37,
#   'Daily Work Load Average': 241.476,
#   'Body Mass Index': 28,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 4},
#  {'ID': 3,
#   'Reason for Absence': 23,
#   'Date': '01/09/2015',
#   'Transportation Expense': 179,
#   'Distance to Work': 51,
#   'Age': 38,
#   'Daily Work Load Average': 241.476,
#   'Body Mass Index': 31,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 4},
#  {'ID': 5,
#   'Reason for Absence': 19,
#   'Date': '08/09/2015',
#   'Transportation Expense': 235,
#   'Distance to Work': 20,
#   'Age': 43,
#   'Daily Work Load Average': 241.476,
#   'Body Mass Index': 38,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 14,
#   'Reason for Absence': 23,
#   'Date': '09/09/2015',
#   'Transportation Expense': 155,
#   'Distance to Work': 12,
#   'Age': 34,
#   'Daily Work Load Average': 241.476,
#   'Body Mass Index': 25,
#   'Education': 1,
#   'Children': 2,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 2},
#  {'ID': 34,
#   'Reason for Absence': 23,
#   'Date': '13/09/2015',
#   'Transportation Expense': 118,
#   'Distance to Work': 10,
#   'Age': 37,
#   'Daily Work Load Average': 241.476,
#   'Body Mass Index': 28,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 3},
#  {'ID': 3,
#   'Reason for Absence': 23,
#   'Date': '14/09/2015',
#   'Transportation Expense': 179,
#   'Distance to Work': 51,
#   'Age': 38,
#   'Daily Work Load Average': 241.476,
#   'Body Mass Index': 31,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 3},
#  {'ID': 15,
#   'Reason for Absence': 23,
#   'Date': '24/09/2015',
#   'Transportation Expense': 291,
#   'Distance to Work': 31,
#   'Age': 40,
#   'Daily Work Load Average': 241.476,
#   'Body Mass Index': 25,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 1,
#   'Absenteeism Time in Hours': 4},
#  {'ID': 20,
#   'Reason for Absence': 22,
#   'Date': '04/09/2015',
#   'Transportation Expense': 260,
#   'Distance to Work': 50,
#   'Age': 36,
#   'Daily Work Load Average': 241.476,
#   'Body Mass Index': 23,
#   'Education': 1,
#   'Children': 4,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 15,
#   'Reason for Absence': 14,
#   'Date': '14/09/2015',
#   'Transportation Expense': 291,
#   'Distance to Work': 31,
#   'Age': 40,
#   'Daily Work Load Average': 241.476,
#   'Body Mass Index': 25,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 1,
#   'Absenteeism Time in Hours': 32},
#  {'ID': 20,
#   'Reason for Absence': 0,
#   'Date': '21/09/2015',
#   'Transportation Expense': 260,
#   'Distance to Work': 50,
#   'Age': 36,
#   'Daily Work Load Average': 241.476,
#   'Body Mass Index': 23,
#   'Education': 1,
#   'Children': 4,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 0},
#  {'ID': 29,
#   'Reason for Absence': 0,
#   'Date': '28/09/2015',
#   'Transportation Expense': 225,
#   'Distance to Work': 26,
#   'Age': 28,
#   'Daily Work Load Average': 241.476,
#   'Body Mass Index': 24,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 2,
#   'Absenteeism Time in Hours': 0},
#  {'ID': 28,
#   'Reason for Absence': 23,
#   'Date': '08/09/2015',
#   'Transportation Expense': 225,
#   'Distance to Work': 26,
#   'Age': 28,
#   'Daily Work Load Average': 241.476,
#   'Body Mass Index': 24,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 2,
#   'Absenteeism Time in Hours': 2},
#  {'ID': 34,
#   'Reason for Absence': 23,
#   'Date': '15/09/2015',
#   'Transportation Expense': 118,
#   'Distance to Work': 10,
#   'Age': 37,
#   'Daily Work Load Average': 241.476,
#   'Body Mass Index': 28,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 2},
#  {'ID': 11,
#   'Reason for Absence': 0,
#   'Date': '22/09/2015',
#   'Transportation Expense': 289,
#   'Distance to Work': 36,
#   'Age': 33,
#   'Daily Work Load Average': 241.476,
#   'Body Mass Index': 30,
#   'Education': 1,
#   'Children': 2,
#   'Pets': 1,
#   'Absenteeism Time in Hours': 0},
#  {'ID': 36,
#   'Reason for Absence': 0,
#   'Date': '29/09/2015',
#   'Transportation Expense': 118,
#   'Distance to Work': 13,
#   'Age': 50,
#   'Daily Work Load Average': 241.476,
#   'Body Mass Index': 31,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 0},
#  {'ID': 28,
#   'Reason for Absence': 18,
#   'Date': '16/09/2015',
#   'Transportation Expense': 225,
#   'Distance to Work': 26,
#   'Age': 28,
#   'Daily Work Load Average': 241.476,
#   'Body Mass Index': 24,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 2,
#   'Absenteeism Time in Hours': 3},
#  {'ID': 3,
#   'Reason for Absence': 23,
#   'Date': '23/09/2015',
#   'Transportation Expense': 179,
#   'Distance to Work': 51,
#   'Age': 38,
#   'Daily Work Load Average': 241.476,
#   'Body Mass Index': 31,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 3},
#  {'ID': 13,
#   'Reason for Absence': 0,
#   'Date': '30/09/2015',
#   'Transportation Expense': 369,
#   'Distance to Work': 17,
#   'Age': 31,
#   'Daily Work Load Average': 241.476,
#   'Body Mass Index': 25,
#   'Education': 1,
#   'Children': 3,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 0},
#  {'ID': 33,
#   'Reason for Absence': 23,
#   'Date': '11/09/2015',
#   'Transportation Expense': 248,
#   'Distance to Work': 25,
#   'Age': 47,
#   'Daily Work Load Average': 241.476,
#   'Body Mass Index': 32,
#   'Education': 1,
#   'Children': 2,
#   'Pets': 1,
#   'Absenteeism Time in Hours': 1},
#  {'ID': 3,
#   'Reason for Absence': 23,
#   'Date': '18/09/2015',
#   'Transportation Expense': 179,
#   'Distance to Work': 51,
#   'Age': 38,
#   'Daily Work Load Average': 241.476,
#   'Body Mass Index': 31,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 3},
#  {'ID': 20,
#   'Reason for Absence': 23,
#   'Date': '25/09/2015',
#   'Transportation Expense': 260,
#   'Distance to Work': 50,
#   'Age': 36,
#   'Daily Work Load Average': 241.476,
#   'Body Mass Index': 23,
#   'Education': 1,
#   'Children': 4,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 4},
#  {'ID': 3,
#   'Reason for Absence': 23,
#   'Date': '06/10/2015',
#   'Transportation Expense': 179,
#   'Distance to Work': 51,
#   'Age': 38,
#   'Daily Work Load Average': 253.465,
#   'Body Mass Index': 31,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 3},
#  {'ID': 34,
#   'Reason for Absence': 23,
#   'Date': '13/10/2015',
#   'Transportation Expense': 118,
#   'Distance to Work': 10,
#   'Age': 37,
#   'Daily Work Load Average': 253.465,
#   'Body Mass Index': 28,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 3},
#  {'ID': 36,
#   'Reason for Absence': 0,
#   'Date': '14/10/2015',
#   'Transportation Expense': 118,
#   'Distance to Work': 13,
#   'Age': 50,
#   'Daily Work Load Average': 253.465,
#   'Body Mass Index': 31,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 0},
#  {'ID': 22,
#   'Reason for Absence': 23,
#   'Date': '15/10/2015',
#   'Transportation Expense': 179,
#   'Distance to Work': 26,
#   'Age': 30,
#   'Daily Work Load Average': 253.465,
#   'Body Mass Index': 19,
#   'Education': 3,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 1},
#  {'ID': 3,
#   'Reason for Absence': 23,
#   'Date': '16/10/2015',
#   'Transportation Expense': 179,
#   'Distance to Work': 51,
#   'Age': 38,
#   'Daily Work Load Average': 253.465,
#   'Body Mass Index': 31,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 3},
#  {'ID': 28,
#   'Reason for Absence': 23,
#   'Date': '16/10/2015',
#   'Transportation Expense': 225,
#   'Distance to Work': 26,
#   'Age': 28,
#   'Daily Work Load Average': 253.465,
#   'Body Mass Index': 24,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 2,
#   'Absenteeism Time in Hours': 3},
#  {'ID': 34,
#   'Reason for Absence': 23,
#   'Date': '06/10/2015',
#   'Transportation Expense': 118,
#   'Distance to Work': 10,
#   'Age': 37,
#   'Daily Work Load Average': 253.465,
#   'Body Mass Index': 28,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 3},
#  {'ID': 28,
#   'Reason for Absence': 23,
#   'Date': '14/10/2015',
#   'Transportation Expense': 225,
#   'Distance to Work': 26,
#   'Age': 28,
#   'Daily Work Load Average': 253.465,
#   'Body Mass Index': 24,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 2,
#   'Absenteeism Time in Hours': 2},
#  {'ID': 33,
#   'Reason for Absence': 23,
#   'Date': '21/10/2015',
#   'Transportation Expense': 248,
#   'Distance to Work': 25,
#   'Age': 47,
#   'Daily Work Load Average': 253.465,
#   'Body Mass Index': 32,
#   'Education': 1,
#   'Children': 2,
#   'Pets': 1,
#   'Absenteeism Time in Hours': 2},
#  {'ID': 15,
#   'Reason for Absence': 23,
#   'Date': '22/10/2015',
#   'Transportation Expense': 291,
#   'Distance to Work': 31,
#   'Age': 40,
#   'Daily Work Load Average': 253.465,
#   'Body Mass Index': 25,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 1,
#   'Absenteeism Time in Hours': 5},
#  {'ID': 3,
#   'Reason for Absence': 23,
#   'Date': '21/10/2015',
#   'Transportation Expense': 179,
#   'Distance to Work': 51,
#   'Age': 38,
#   'Daily Work Load Average': 253.465,
#   'Body Mass Index': 31,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 28,
#   'Reason for Absence': 23,
#   'Date': '21/10/2015',
#   'Transportation Expense': 225,
#   'Distance to Work': 26,
#   'Age': 28,
#   'Daily Work Load Average': 253.465,
#   'Body Mass Index': 24,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 2,
#   'Absenteeism Time in Hours': 3},
#  {'ID': 20,
#   'Reason for Absence': 19,
#   'Date': '22/10/2015',
#   'Transportation Expense': 260,
#   'Distance to Work': 50,
#   'Age': 36,
#   'Daily Work Load Average': 253.465,
#   'Body Mass Index': 23,
#   'Education': 1,
#   'Children': 4,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 16},
#  {'ID': 15,
#   'Reason for Absence': 14,
#   'Date': '13/10/2015',
#   'Transportation Expense': 291,
#   'Distance to Work': 31,
#   'Age': 40,
#   'Daily Work Load Average': 253.465,
#   'Body Mass Index': 25,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 1,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 28,
#   'Reason for Absence': 28,
#   'Date': '20/10/2015',
#   'Transportation Expense': 225,
#   'Distance to Work': 26,
#   'Age': 28,
#   'Daily Work Load Average': 253.465,
#   'Body Mass Index': 24,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 2,
#   'Absenteeism Time in Hours': 2},
#  {'ID': 11,
#   'Reason for Absence': 26,
#   'Date': '21/10/2015',
#   'Transportation Expense': 289,
#   'Distance to Work': 36,
#   'Age': 33,
#   'Daily Work Load Average': 253.465,
#   'Body Mass Index': 30,
#   'Education': 1,
#   'Children': 2,
#   'Pets': 1,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 10,
#   'Reason for Absence': 23,
#   'Date': '23/10/2015',
#   'Transportation Expense': 361,
#   'Distance to Work': 52,
#   'Age': 28,
#   'Daily Work Load Average': 253.465,
#   'Body Mass Index': 27,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 4,
#   'Absenteeism Time in Hours': 1},
#  {'ID': 20,
#   'Reason for Absence': 28,
#   'Date': '30/10/2015',
#   'Transportation Expense': 260,
#   'Distance to Work': 50,
#   'Age': 36,
#   'Daily Work Load Average': 253.465,
#   'Body Mass Index': 23,
#   'Education': 1,
#   'Children': 4,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 3},
#  {'ID': 3,
#   'Reason for Absence': 23,
#   'Date': '05/11/2015',
#   'Transportation Expense': 179,
#   'Distance to Work': 51,
#   'Age': 38,
#   'Daily Work Load Average': 306.345,
#   'Body Mass Index': 31,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 1},
#  {'ID': 28,
#   'Reason for Absence': 23,
#   'Date': '04/11/2015',
#   'Transportation Expense': 225,
#   'Distance to Work': 26,
#   'Age': 28,
#   'Daily Work Load Average': 306.345,
#   'Body Mass Index': 24,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 2,
#   'Absenteeism Time in Hours': 1},
#  {'ID': 3,
#   'Reason for Absence': 13,
#   'Date': '05/11/2015',
#   'Transportation Expense': 179,
#   'Distance to Work': 51,
#   'Age': 38,
#   'Daily Work Load Average': 306.345,
#   'Body Mass Index': 31,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 17,
#   'Reason for Absence': 21,
#   'Date': '12/11/2015',
#   'Transportation Expense': 179,
#   'Distance to Work': 22,
#   'Age': 40,
#   'Daily Work Load Average': 306.345,
#   'Body Mass Index': 22,
#   'Education': 2,
#   'Children': 2,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 15,
#   'Reason for Absence': 23,
#   'Date': '19/11/2015',
#   'Transportation Expense': 291,
#   'Distance to Work': 31,
#   'Age': 40,
#   'Daily Work Load Average': 306.345,
#   'Body Mass Index': 25,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 1,
#   'Absenteeism Time in Hours': 5},
#  {'ID': 14,
#   'Reason for Absence': 10,
#   'Date': '02/11/2015',
#   'Transportation Expense': 155,
#   'Distance to Work': 12,
#   'Age': 34,
#   'Daily Work Load Average': 306.345,
#   'Body Mass Index': 25,
#   'Education': 1,
#   'Children': 2,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 32},
#  {'ID': 6,
#   'Reason for Absence': 22,
#   'Date': '09/11/2015',
#   'Transportation Expense': 189,
#   'Distance to Work': 29,
#   'Age': 33,
#   'Daily Work Load Average': 306.345,
#   'Body Mass Index': 25,
#   'Education': 1,
#   'Children': 2,
#   'Pets': 2,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 15,
#   'Reason for Absence': 14,
#   'Date': '16/11/2015',
#   'Transportation Expense': 291,
#   'Distance to Work': 31,
#   'Age': 40,
#   'Daily Work Load Average': 306.345,
#   'Body Mass Index': 25,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 1,
#   'Absenteeism Time in Hours': 40},
#  {'ID': 28,
#   'Reason for Absence': 23,
#   'Date': '18/11/2015',
#   'Transportation Expense': 225,
#   'Distance to Work': 26,
#   'Age': 28,
#   'Daily Work Load Average': 306.345,
#   'Body Mass Index': 24,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 2,
#   'Absenteeism Time in Hours': 1},
#  {'ID': 14,
#   'Reason for Absence': 6,
#   'Date': '20/11/2015',
#   'Transportation Expense': 155,
#   'Distance to Work': 12,
#   'Age': 34,
#   'Daily Work Load Average': 306.345,
#   'Body Mass Index': 25,
#   'Education': 1,
#   'Children': 2,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 28,
#   'Reason for Absence': 23,
#   'Date': '18/11/2015',
#   'Transportation Expense': 225,
#   'Distance to Work': 26,
#   'Age': 28,
#   'Daily Work Load Average': 306.345,
#   'Body Mass Index': 24,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 2,
#   'Absenteeism Time in Hours': 3},
#  {'ID': 17,
#   'Reason for Absence': 21,
#   'Date': '25/11/2015',
#   'Transportation Expense': 179,
#   'Distance to Work': 22,
#   'Age': 40,
#   'Daily Work Load Average': 306.345,
#   'Body Mass Index': 22,
#   'Education': 2,
#   'Children': 2,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 28,
#   'Reason for Absence': 13,
#   'Date': '20/11/2015',
#   'Transportation Expense': 225,
#   'Distance to Work': 26,
#   'Age': 28,
#   'Daily Work Load Average': 306.345,
#   'Body Mass Index': 24,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 2,
#   'Absenteeism Time in Hours': 3},
#  {'ID': 20,
#   'Reason for Absence': 28,
#   'Date': '27/11/2015',
#   'Transportation Expense': 260,
#   'Distance to Work': 50,
#   'Age': 36,
#   'Daily Work Load Average': 306.345,
#   'Body Mass Index': 23,
#   'Education': 1,
#   'Children': 4,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 4},
#  {'ID': 33,
#   'Reason for Absence': 28,
#   'Date': '02/11/2015',
#   'Transportation Expense': 248,
#   'Distance to Work': 25,
#   'Age': 47,
#   'Daily Work Load Average': 306.345,
#   'Body Mass Index': 32,
#   'Education': 1,
#   'Children': 2,
#   'Pets': 1,
#   'Absenteeism Time in Hours': 1},
#  {'ID': 28,
#   'Reason for Absence': 28,
#   'Date': '10/11/2015',
#   'Transportation Expense': 225,
#   'Distance to Work': 26,
#   'Age': 28,
#   'Daily Work Load Average': 306.345,
#   'Body Mass Index': 24,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 2,
#   'Absenteeism Time in Hours': 3},
#  {'ID': 11,
#   'Reason for Absence': 7,
#   'Date': '11/11/2015',
#   'Transportation Expense': 289,
#   'Distance to Work': 36,
#   'Age': 33,
#   'Daily Work Load Average': 306.345,
#   'Body Mass Index': 30,
#   'Education': 1,
#   'Children': 2,
#   'Pets': 1,
#   'Absenteeism Time in Hours': 24},
#  {'ID': 15,
#   'Reason for Absence': 23,
#   'Date': '26/11/2015',
#   'Transportation Expense': 291,
#   'Distance to Work': 31,
#   'Age': 40,
#   'Daily Work Load Average': 306.345,
#   'Body Mass Index': 25,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 1,
#   'Absenteeism Time in Hours': 3},
#  {'ID': 33,
#   'Reason for Absence': 23,
#   'Date': '01/12/2015',
#   'Transportation Expense': 248,
#   'Distance to Work': 25,
#   'Age': 47,
#   'Daily Work Load Average': 261.306,
#   'Body Mass Index': 32,
#   'Education': 1,
#   'Children': 2,
#   'Pets': 1,
#   'Absenteeism Time in Hours': 1},
#  {'ID': 34,
#   'Reason for Absence': 19,
#   'Date': '01/12/2015',
#   'Transportation Expense': 118,
#   'Distance to Work': 10,
#   'Age': 37,
#   'Daily Work Load Average': 261.306,
#   'Body Mass Index': 28,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 64},
#  {'ID': 36,
#   'Reason for Absence': 23,
#   'Date': '02/12/2015',
#   'Transportation Expense': 118,
#   'Distance to Work': 13,
#   'Age': 50,
#   'Daily Work Load Average': 261.306,
#   'Body Mass Index': 31,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 2},
#  {'ID': 1,
#   'Reason for Absence': 26,
#   'Date': '02/12/2015',
#   'Transportation Expense': 235,
#   'Distance to Work': 11,
#   'Age': 37,
#   'Daily Work Load Average': 261.306,
#   'Body Mass Index': 29,
#   'Education': 3,
#   'Children': 1,
#   'Pets': 1,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 28,
#   'Reason for Absence': 23,
#   'Date': '03/12/2015',
#   'Transportation Expense': 225,
#   'Distance to Work': 26,
#   'Age': 28,
#   'Daily Work Load Average': 261.306,
#   'Body Mass Index': 24,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 2,
#   'Absenteeism Time in Hours': 2},
#  {'ID': 20,
#   'Reason for Absence': 26,
#   'Date': '04/12/2015',
#   'Transportation Expense': 260,
#   'Distance to Work': 50,
#   'Age': 36,
#   'Daily Work Load Average': 261.306,
#   'Body Mass Index': 23,
#   'Education': 1,
#   'Children': 4,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 34,
#   'Reason for Absence': 19,
#   'Date': '08/12/2015',
#   'Transportation Expense': 118,
#   'Distance to Work': 10,
#   'Age': 37,
#   'Daily Work Load Average': 261.306,
#   'Body Mass Index': 28,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 56},
#  {'ID': 10,
#   'Reason for Absence': 22,
#   'Date': '09/12/2015',
#   'Transportation Expense': 361,
#   'Distance to Work': 52,
#   'Age': 28,
#   'Daily Work Load Average': 261.306,
#   'Body Mass Index': 27,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 4,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 28,
#   'Reason for Absence': 28,
#   'Date': '10/12/2015',
#   'Transportation Expense': 225,
#   'Distance to Work': 26,
#   'Age': 28,
#   'Daily Work Load Average': 261.306,
#   'Body Mass Index': 24,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 2,
#   'Absenteeism Time in Hours': 3},
#  {'ID': 20,
#   'Reason for Absence': 28,
#   'Date': '11/12/2015',
#   'Transportation Expense': 260,
#   'Distance to Work': 50,
#   'Age': 36,
#   'Daily Work Load Average': 261.306,
#   'Body Mass Index': 23,
#   'Education': 1,
#   'Children': 4,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 3},
#  {'ID': 28,
#   'Reason for Absence': 23,
#   'Date': '15/12/2015',
#   'Transportation Expense': 225,
#   'Distance to Work': 26,
#   'Age': 28,
#   'Daily Work Load Average': 261.306,
#   'Body Mass Index': 24,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 2,
#   'Absenteeism Time in Hours': 2},
#  {'ID': 10,
#   'Reason for Absence': 22,
#   'Date': '16/12/2015',
#   'Transportation Expense': 361,
#   'Distance to Work': 52,
#   'Age': 28,
#   'Daily Work Load Average': 261.306,
#   'Body Mass Index': 27,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 4,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 34,
#   'Reason for Absence': 27,
#   'Date': '11/12/2015',
#   'Transportation Expense': 118,
#   'Distance to Work': 10,
#   'Age': 37,
#   'Daily Work Load Average': 261.306,
#   'Body Mass Index': 28,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 2},
#  {'ID': 24,
#   'Reason for Absence': 19,
#   'Date': '18/12/2015',
#   'Transportation Expense': 246,
#   'Distance to Work': 25,
#   'Age': 41,
#   'Daily Work Load Average': 261.306,
#   'Body Mass Index': 23,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 28,
#   'Reason for Absence': 23,
#   'Date': '18/12/2015',
#   'Transportation Expense': 225,
#   'Distance to Work': 26,
#   'Age': 28,
#   'Daily Work Load Average': 261.306,
#   'Body Mass Index': 24,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 2,
#   'Absenteeism Time in Hours': 2},
#  {'ID': 28,
#   'Reason for Absence': 23,
#   'Date': '06/01/2016',
#   'Transportation Expense': 225,
#   'Distance to Work': 26,
#   'Age': 28,
#   'Daily Work Load Average': 308.593,
#   'Body Mass Index': 24,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 2,
#   'Absenteeism Time in Hours': 1},
#  {'ID': 34,
#   'Reason for Absence': 19,
#   'Date': '04/01/2016',
#   'Transportation Expense': 118,
#   'Distance to Work': 10,
#   'Age': 37,
#   'Daily Work Load Average': 308.593,
#   'Body Mass Index': 28,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 1},
#  {'ID': 34,
#   'Reason for Absence': 27,
#   'Date': '05/01/2016',
#   'Transportation Expense': 118,
#   'Distance to Work': 10,
#   'Age': 37,
#   'Daily Work Load Average': 308.593,
#   'Body Mass Index': 28,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 1},
#  {'ID': 14,
#   'Reason for Absence': 18,
#   'Date': '05/01/2016',
#   'Transportation Expense': 155,
#   'Distance to Work': 12,
#   'Age': 34,
#   'Daily Work Load Average': 308.593,
#   'Body Mass Index': 25,
#   'Education': 1,
#   'Children': 2,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 28,
#   'Reason for Absence': 27,
#   'Date': '06/01/2016',
#   'Transportation Expense': 225,
#   'Distance to Work': 26,
#   'Age': 28,
#   'Daily Work Load Average': 308.593,
#   'Body Mass Index': 24,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 2,
#   'Absenteeism Time in Hours': 2},
#  {'ID': 27,
#   'Reason for Absence': 23,
#   'Date': '07/01/2016',
#   'Transportation Expense': 184,
#   'Distance to Work': 42,
#   'Age': 27,
#   'Daily Work Load Average': 308.593,
#   'Body Mass Index': 21,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 2},
#  {'ID': 28,
#   'Reason for Absence': 28,
#   'Date': '07/01/2016',
#   'Transportation Expense': 225,
#   'Distance to Work': 26,
#   'Age': 28,
#   'Daily Work Load Average': 308.593,
#   'Body Mass Index': 24,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 2,
#   'Absenteeism Time in Hours': 2},
#  {'ID': 28,
#   'Reason for Absence': 27,
#   'Date': '08/01/2016',
#   'Transportation Expense': 225,
#   'Distance to Work': 26,
#   'Age': 28,
#   'Daily Work Load Average': 308.593,
#   'Body Mass Index': 24,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 2,
#   'Absenteeism Time in Hours': 1},
#  {'ID': 34,
#   'Reason for Absence': 27,
#   'Date': '11/01/2016',
#   'Transportation Expense': 118,
#   'Distance to Work': 10,
#   'Age': 37,
#   'Daily Work Load Average': 308.593,
#   'Body Mass Index': 28,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 2},
#  {'ID': 28,
#   'Reason for Absence': 27,
#   'Date': '12/01/2016',
#   'Transportation Expense': 225,
#   'Distance to Work': 26,
#   'Age': 28,
#   'Daily Work Load Average': 308.593,
#   'Body Mass Index': 24,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 2,
#   'Absenteeism Time in Hours': 2},
#  {'ID': 34,
#   'Reason for Absence': 27,
#   'Date': '12/01/2016',
#   'Transportation Expense': 118,
#   'Distance to Work': 10,
#   'Age': 37,
#   'Daily Work Load Average': 308.593,
#   'Body Mass Index': 28,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 2},
#  {'ID': 34,
#   'Reason for Absence': 27,
#   'Date': '13/01/2016',
#   'Transportation Expense': 118,
#   'Distance to Work': 10,
#   'Age': 37,
#   'Daily Work Load Average': 308.593,
#   'Body Mass Index': 28,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 2},
#  {'ID': 34,
#   'Reason for Absence': 27,
#   'Date': '14/01/2016',
#   'Transportation Expense': 118,
#   'Distance to Work': 10,
#   'Age': 37,
#   'Daily Work Load Average': 308.593,
#   'Body Mass Index': 28,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 2},
#  {'ID': 34,
#   'Reason for Absence': 27,
#   'Date': '15/01/2016',
#   'Transportation Expense': 118,
#   'Distance to Work': 10,
#   'Age': 37,
#   'Daily Work Load Average': 308.593,
#   'Body Mass Index': 28,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 2},
#  {'ID': 34,
#   'Reason for Absence': 27,
#   'Date': '11/01/2016',
#   'Transportation Expense': 118,
#   'Distance to Work': 10,
#   'Age': 37,
#   'Daily Work Load Average': 308.593,
#   'Body Mass Index': 28,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 2},
#  {'ID': 34,
#   'Reason for Absence': 27,
#   'Date': '12/01/2016',
#   'Transportation Expense': 118,
#   'Distance to Work': 10,
#   'Age': 37,
#   'Daily Work Load Average': 308.593,
#   'Body Mass Index': 28,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 2},
#  {'ID': 22,
#   'Reason for Absence': 18,
#   'Date': '12/01/2016',
#   'Transportation Expense': 179,
#   'Distance to Work': 26,
#   'Age': 30,
#   'Daily Work Load Average': 308.593,
#   'Body Mass Index': 19,
#   'Education': 3,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 11,
#   'Reason for Absence': 18,
#   'Date': '12/01/2016',
#   'Transportation Expense': 289,
#   'Distance to Work': 36,
#   'Age': 33,
#   'Daily Work Load Average': 308.593,
#   'Body Mass Index': 30,
#   'Education': 1,
#   'Children': 2,
#   'Pets': 1,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 34,
#   'Reason for Absence': 27,
#   'Date': '13/01/2016',
#   'Transportation Expense': 118,
#   'Distance to Work': 10,
#   'Age': 37,
#   'Daily Work Load Average': 308.593,
#   'Body Mass Index': 28,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 2},
#  {'ID': 27,
#   'Reason for Absence': 23,
#   'Date': '21/01/2016',
#   'Transportation Expense': 184,
#   'Distance to Work': 42,
#   'Age': 27,
#   'Daily Work Load Average': 308.593,
#   'Body Mass Index': 21,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 2},
#  {'ID': 34,
#   'Reason for Absence': 27,
#   'Date': '28/01/2016',
#   'Transportation Expense': 118,
#   'Distance to Work': 10,
#   'Age': 37,
#   'Daily Work Load Average': 308.593,
#   'Body Mass Index': 28,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 2},
#  {'ID': 34,
#   'Reason for Absence': 27,
#   'Date': '25/01/2016',
#   'Transportation Expense': 118,
#   'Distance to Work': 10,
#   'Age': 37,
#   'Daily Work Load Average': 308.593,
#   'Body Mass Index': 28,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 0},
#  {'ID': 28,
#   'Reason for Absence': 23,
#   'Date': '26/01/2016',
#   'Transportation Expense': 225,
#   'Distance to Work': 26,
#   'Age': 28,
#   'Daily Work Load Average': 308.593,
#   'Body Mass Index': 24,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 2,
#   'Absenteeism Time in Hours': 1},
#  {'ID': 11,
#   'Reason for Absence': 22,
#   'Date': '28/01/2016',
#   'Transportation Expense': 289,
#   'Distance to Work': 36,
#   'Age': 33,
#   'Daily Work Load Average': 308.593,
#   'Body Mass Index': 30,
#   'Education': 1,
#   'Children': 2,
#   'Pets': 1,
#   'Absenteeism Time in Hours': 3},
#  {'ID': 27,
#   'Reason for Absence': 23,
#   'Date': '05/02/2016',
#   'Transportation Expense': 184,
#   'Distance to Work': 42,
#   'Age': 27,
#   'Daily Work Load Average': 302.585,
#   'Body Mass Index': 21,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 1},
#  {'ID': 24,
#   'Reason for Absence': 1,
#   'Date': '03/02/2016',
#   'Transportation Expense': 246,
#   'Distance to Work': 25,
#   'Age': 41,
#   'Daily Work Load Average': 302.585,
#   'Body Mass Index': 23,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 3,
#   'Reason for Absence': 11,
#   'Date': '10/02/2016',
#   'Transportation Expense': 179,
#   'Distance to Work': 51,
#   'Age': 38,
#   'Daily Work Load Average': 302.585,
#   'Body Mass Index': 31,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 14,
#   'Reason for Absence': 28,
#   'Date': '11/02/2016',
#   'Transportation Expense': 155,
#   'Distance to Work': 12,
#   'Age': 34,
#   'Daily Work Load Average': 302.585,
#   'Body Mass Index': 25,
#   'Education': 1,
#   'Children': 2,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 2},
#  {'ID': 6,
#   'Reason for Absence': 23,
#   'Date': '11/02/2016',
#   'Transportation Expense': 189,
#   'Distance to Work': 29,
#   'Age': 33,
#   'Daily Work Load Average': 302.585,
#   'Body Mass Index': 25,
#   'Education': 1,
#   'Children': 2,
#   'Pets': 2,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 20,
#   'Reason for Absence': 28,
#   'Date': '12/02/2016',
#   'Transportation Expense': 260,
#   'Distance to Work': 50,
#   'Age': 36,
#   'Daily Work Load Average': 302.585,
#   'Body Mass Index': 23,
#   'Education': 1,
#   'Children': 4,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 2},
#  {'ID': 11,
#   'Reason for Absence': 22,
#   'Date': '12/02/2016',
#   'Transportation Expense': 289,
#   'Distance to Work': 36,
#   'Age': 33,
#   'Daily Work Load Average': 302.585,
#   'Body Mass Index': 30,
#   'Education': 1,
#   'Children': 2,
#   'Pets': 1,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 31,
#   'Reason for Absence': 11,
#   'Date': '08/02/2016',
#   'Transportation Expense': 388,
#   'Distance to Work': 15,
#   'Age': 50,
#   'Daily Work Load Average': 302.585,
#   'Body Mass Index': 24,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 31,
#   'Reason for Absence': 1,
#   'Date': '09/02/2016',
#   'Transportation Expense': 388,
#   'Distance to Work': 15,
#   'Age': 50,
#   'Daily Work Load Average': 302.585,
#   'Body Mass Index': 24,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 28,
#   'Reason for Absence': 28,
#   'Date': '15/02/2016',
#   'Transportation Expense': 225,
#   'Distance to Work': 26,
#   'Age': 28,
#   'Daily Work Load Average': 302.585,
#   'Body Mass Index': 24,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 2,
#   'Absenteeism Time in Hours': 2},
#  {'ID': 28,
#   'Reason for Absence': 23,
#   'Date': '09/02/2016',
#   'Transportation Expense': 225,
#   'Distance to Work': 26,
#   'Age': 28,
#   'Daily Work Load Average': 302.585,
#   'Body Mass Index': 24,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 2,
#   'Absenteeism Time in Hours': 2},
#  {'ID': 22,
#   'Reason for Absence': 23,
#   'Date': '16/02/2016',
#   'Transportation Expense': 179,
#   'Distance to Work': 26,
#   'Age': 30,
#   'Daily Work Load Average': 302.585,
#   'Body Mass Index': 19,
#   'Education': 3,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 1},
#  {'ID': 27,
#   'Reason for Absence': 23,
#   'Date': '23/02/2016',
#   'Transportation Expense': 184,
#   'Distance to Work': 42,
#   'Age': 27,
#   'Daily Work Load Average': 302.585,
#   'Body Mass Index': 21,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 28,
#   'Reason for Absence': 25,
#   'Date': '25/02/2016',
#   'Transportation Expense': 225,
#   'Distance to Work': 26,
#   'Age': 28,
#   'Daily Work Load Average': 302.585,
#   'Body Mass Index': 24,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 2,
#   'Absenteeism Time in Hours': 3},
#  {'ID': 18,
#   'Reason for Absence': 18,
#   'Date': '15/02/2016',
#   'Transportation Expense': 330,
#   'Distance to Work': 16,
#   'Age': 28,
#   'Daily Work Load Average': 302.585,
#   'Body Mass Index': 25,
#   'Education': 2,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 18,
#   'Reason for Absence': 23,
#   'Date': '16/02/2016',
#   'Transportation Expense': 330,
#   'Distance to Work': 16,
#   'Age': 28,
#   'Daily Work Load Average': 302.585,
#   'Body Mass Index': 25,
#   'Education': 2,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 1},
#  {'ID': 28,
#   'Reason for Absence': 23,
#   'Date': '17/02/2016',
#   'Transportation Expense': 225,
#   'Distance to Work': 26,
#   'Age': 28,
#   'Daily Work Load Average': 302.585,
#   'Body Mass Index': 24,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 2,
#   'Absenteeism Time in Hours': 1},
#  {'ID': 6,
#   'Reason for Absence': 19,
#   'Date': '25/02/2016',
#   'Transportation Expense': 189,
#   'Distance to Work': 29,
#   'Age': 33,
#   'Daily Work Load Average': 302.585,
#   'Body Mass Index': 25,
#   'Education': 1,
#   'Children': 2,
#   'Pets': 2,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 19,
#   'Reason for Absence': 28,
#   'Date': '01/03/2016',
#   'Transportation Expense': 291,
#   'Distance to Work': 50,
#   'Age': 32,
#   'Daily Work Load Average': 343.25300000000004,
#   'Body Mass Index': 23,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 2},
#  {'ID': 20,
#   'Reason for Absence': 19,
#   'Date': '01/03/2016',
#   'Transportation Expense': 260,
#   'Distance to Work': 50,
#   'Age': 36,
#   'Daily Work Load Average': 343.25300000000004,
#   'Body Mass Index': 23,
#   'Education': 1,
#   'Children': 4,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 30,
#   'Reason for Absence': 19,
#   'Date': '08/03/2016',
#   'Transportation Expense': 157,
#   'Distance to Work': 27,
#   'Age': 29,
#   'Daily Work Load Average': 343.25300000000004,
#   'Body Mass Index': 22,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 3},
#  {'ID': 17,
#   'Reason for Absence': 17,
#   'Date': '15/03/2016',
#   'Transportation Expense': 179,
#   'Distance to Work': 22,
#   'Age': 40,
#   'Daily Work Load Average': 343.25300000000004,
#   'Body Mass Index': 22,
#   'Education': 2,
#   'Children': 2,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 15,
#   'Reason for Absence': 22,
#   'Date': '16/03/2016',
#   'Transportation Expense': 291,
#   'Distance to Work': 31,
#   'Age': 40,
#   'Daily Work Load Average': 343.25300000000004,
#   'Body Mass Index': 25,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 1,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 20,
#   'Reason for Absence': 13,
#   'Date': '02/03/2016',
#   'Transportation Expense': 260,
#   'Distance to Work': 50,
#   'Age': 36,
#   'Daily Work Load Average': 343.25300000000004,
#   'Body Mass Index': 23,
#   'Education': 1,
#   'Children': 4,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 22,
#   'Reason for Absence': 13,
#   'Date': '03/03/2016',
#   'Transportation Expense': 179,
#   'Distance to Work': 26,
#   'Age': 30,
#   'Daily Work Load Average': 343.25300000000004,
#   'Body Mass Index': 19,
#   'Education': 3,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 33,
#   'Reason for Absence': 14,
#   'Date': '04/03/2016',
#   'Transportation Expense': 248,
#   'Distance to Work': 25,
#   'Age': 47,
#   'Daily Work Load Average': 343.25300000000004,
#   'Body Mass Index': 32,
#   'Education': 1,
#   'Children': 2,
#   'Pets': 1,
#   'Absenteeism Time in Hours': 3},
#  {'ID': 20,
#   'Reason for Absence': 13,
#   'Date': '04/03/2016',
#   'Transportation Expense': 260,
#   'Distance to Work': 50,
#   'Age': 36,
#   'Daily Work Load Average': 343.25300000000004,
#   'Body Mass Index': 23,
#   'Education': 1,
#   'Children': 4,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 40},
#  {'ID': 17,
#   'Reason for Absence': 11,
#   'Date': '07/03/2016',
#   'Transportation Expense': 179,
#   'Distance to Work': 22,
#   'Age': 40,
#   'Daily Work Load Average': 343.25300000000004,
#   'Body Mass Index': 22,
#   'Education': 2,
#   'Children': 2,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 40},
#  {'ID': 14,
#   'Reason for Absence': 1,
#   'Date': '14/03/2016',
#   'Transportation Expense': 155,
#   'Distance to Work': 12,
#   'Age': 34,
#   'Daily Work Load Average': 343.25300000000004,
#   'Body Mass Index': 25,
#   'Education': 1,
#   'Children': 2,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 16},
#  {'ID': 20,
#   'Reason for Absence': 26,
#   'Date': '21/03/2016',
#   'Transportation Expense': 260,
#   'Distance to Work': 50,
#   'Age': 36,
#   'Daily Work Load Average': 343.25300000000004,
#   'Body Mass Index': 23,
#   'Education': 1,
#   'Children': 4,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 16},
#  {'ID': 14,
#   'Reason for Absence': 13,
#   'Date': '22/03/2016',
#   'Transportation Expense': 155,
#   'Distance to Work': 12,
#   'Age': 34,
#   'Daily Work Load Average': 343.25300000000004,
#   'Body Mass Index': 25,
#   'Education': 1,
#   'Children': 2,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 11,
#   'Reason for Absence': 6,
#   'Date': '24/03/2016',
#   'Transportation Expense': 289,
#   'Distance to Work': 36,
#   'Age': 33,
#   'Daily Work Load Average': 343.25300000000004,
#   'Body Mass Index': 30,
#   'Education': 1,
#   'Children': 2,
#   'Pets': 1,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 17,
#   'Reason for Absence': 8,
#   'Date': '24/03/2016',
#   'Transportation Expense': 179,
#   'Distance to Work': 22,
#   'Age': 40,
#   'Daily Work Load Average': 343.25300000000004,
#   'Body Mass Index': 22,
# ...
#   'Reason for Absence': 27,
#   'Date': '23/03/2018',
#   'Transportation Expense': 179,
#   'Distance to Work': 51,
#   'Age': 38,
#   'Daily Work Load Average': 222.196,
#   'Body Mass Index': 31,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 3},
#  {'ID': 3,
#   'Reason for Absence': 27,
#   'Date': '27/03/2018',
#   'Transportation Expense': 179,
#   'Distance to Work': 51,
#   'Age': 38,
#   'Daily Work Load Average': 222.196,
#   'Body Mass Index': 31,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 3},
#  {'ID': 16,
#   'Reason for Absence': 23,
#   'Date': '28/03/2018',
#   'Transportation Expense': 118,
#   'Distance to Work': 15,
#   'Age': 46,
#   'Daily Work Load Average': 222.196,
#   'Body Mass Index': 25,
#   'Education': 1,
#   'Children': 2,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 14,
#   'Reason for Absence': 13,
#   'Date': '28/03/2018',
#   'Transportation Expense': 155,
#   'Distance to Work': 12,
#   'Age': 34,
#   'Daily Work Load Average': 222.196,
#   'Body Mass Index': 25,
#   'Education': 1,
#   'Children': 2,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 24},
#  {'ID': 3,
#   'Reason for Absence': 27,
#   'Date': '28/03/2018',
#   'Transportation Expense': 179,
#   'Distance to Work': 51,
#   'Age': 38,
#   'Daily Work Load Average': 222.196,
#   'Body Mass Index': 31,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 3},
#  {'ID': 3,
#   'Reason for Absence': 27,
#   'Date': '29/03/2018',
#   'Transportation Expense': 179,
#   'Distance to Work': 51,
#   'Age': 38,
#   'Daily Work Load Average': 222.196,
#   'Body Mass Index': 31,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 3},
#  {'ID': 22,
#   'Reason for Absence': 13,
#   'Date': '26/03/2018',
#   'Transportation Expense': 179,
#   'Distance to Work': 26,
#   'Age': 30,
#   'Daily Work Load Average': 222.196,
#   'Body Mass Index': 19,
#   'Education': 3,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 2},
#  {'ID': 11,
#   'Reason for Absence': 19,
#   'Date': '26/03/2018',
#   'Transportation Expense': 289,
#   'Distance to Work': 36,
#   'Age': 33,
#   'Daily Work Load Average': 222.196,
#   'Body Mass Index': 30,
#   'Education': 1,
#   'Children': 2,
#   'Pets': 1,
#   'Absenteeism Time in Hours': 104},
#  {'ID': 13,
#   'Reason for Absence': 22,
#   'Date': '28/03/2018',
#   'Transportation Expense': 369,
#   'Distance to Work': 17,
#   'Age': 31,
#   'Daily Work Load Average': 222.196,
#   'Body Mass Index': 25,
#   'Education': 1,
#   'Children': 3,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 28,
#   'Reason for Absence': 13,
#   'Date': '02/04/2018',
#   'Transportation Expense': 225,
#   'Distance to Work': 26,
#   'Age': 28,
#   'Daily Work Load Average': 246.28799999999998,
#   'Body Mass Index': 24,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 2,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 34,
#   'Reason for Absence': 10,
#   'Date': '02/04/2018',
#   'Transportation Expense': 118,
#   'Distance to Work': 10,
#   'Age': 37,
#   'Daily Work Load Average': 246.28799999999998,
#   'Body Mass Index': 28,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 10,
#   'Reason for Absence': 19,
#   'Date': '03/04/2018',
#   'Transportation Expense': 361,
#   'Distance to Work': 52,
#   'Age': 28,
#   'Daily Work Load Average': 246.28799999999998,
#   'Body Mass Index': 27,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 4,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 33,
#   'Reason for Absence': 19,
#   'Date': '04/04/2018',
#   'Transportation Expense': 248,
#   'Distance to Work': 25,
#   'Age': 47,
#   'Daily Work Load Average': 246.28799999999998,
#   'Body Mass Index': 32,
#   'Education': 1,
#   'Children': 2,
#   'Pets': 1,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 6,
#   'Reason for Absence': 13,
#   'Date': '05/04/2018',
#   'Transportation Expense': 189,
#   'Distance to Work': 29,
#   'Age': 33,
#   'Daily Work Load Average': 246.28799999999998,
#   'Body Mass Index': 25,
#   'Education': 1,
#   'Children': 2,
#   'Pets': 2,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 22,
#   'Reason for Absence': 27,
#   'Date': '06/04/2018',
#   'Transportation Expense': 179,
#   'Distance to Work': 26,
#   'Age': 30,
#   'Daily Work Load Average': 246.28799999999998,
#   'Body Mass Index': 19,
#   'Education': 3,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 2},
#  {'ID': 13,
#   'Reason for Absence': 7,
#   'Date': '09/04/2018',
#   'Transportation Expense': 369,
#   'Distance to Work': 17,
#   'Age': 31,
#   'Daily Work Load Average': 246.28799999999998,
#   'Body Mass Index': 25,
#   'Education': 1,
#   'Children': 3,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 24},
#  {'ID': 17,
#   'Reason for Absence': 16,
#   'Date': '10/04/2018',
#   'Transportation Expense': 179,
#   'Distance to Work': 22,
#   'Age': 40,
#   'Daily Work Load Average': 246.28799999999998,
#   'Body Mass Index': 22,
#   'Education': 2,
#   'Children': 2,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 2},
#  {'ID': 36,
#   'Reason for Absence': 23,
#   'Date': '10/04/2018',
#   'Transportation Expense': 118,
#   'Distance to Work': 13,
#   'Age': 50,
#   'Daily Work Load Average': 246.28799999999998,
#   'Body Mass Index': 31,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 3},
#  {'ID': 10,
#   'Reason for Absence': 23,
#   'Date': '10/04/2018',
#   'Transportation Expense': 361,
#   'Distance to Work': 52,
#   'Age': 28,
#   'Daily Work Load Average': 246.28799999999998,
#   'Body Mass Index': 27,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 4,
#   'Absenteeism Time in Hours': 2},
#  {'ID': 34,
#   'Reason for Absence': 10,
#   'Date': '11/04/2018',
#   'Transportation Expense': 118,
#   'Distance to Work': 10,
#   'Age': 37,
#   'Daily Work Load Average': 246.28799999999998,
#   'Body Mass Index': 28,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 2},
#  {'ID': 1,
#   'Reason for Absence': 22,
#   'Date': '13/04/2018',
#   'Transportation Expense': 235,
#   'Distance to Work': 11,
#   'Age': 37,
#   'Daily Work Load Average': 246.28799999999998,
#   'Body Mass Index': 29,
#   'Education': 3,
#   'Children': 1,
#   'Pets': 1,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 22,
#   'Reason for Absence': 27,
#   'Date': '13/04/2018',
#   'Transportation Expense': 179,
#   'Distance to Work': 26,
#   'Age': 30,
#   'Daily Work Load Average': 246.28799999999998,
#   'Body Mass Index': 19,
#   'Education': 3,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 2},
#  {'ID': 28,
#   'Reason for Absence': 19,
#   'Date': '16/04/2018',
#   'Transportation Expense': 225,
#   'Distance to Work': 26,
#   'Age': 28,
#   'Daily Work Load Average': 246.28799999999998,
#   'Body Mass Index': 24,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 2,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 25,
#   'Reason for Absence': 16,
#   'Date': '17/04/2018',
#   'Transportation Expense': 235,
#   'Distance to Work': 16,
#   'Age': 32,
#   'Daily Work Load Average': 246.28799999999998,
#   'Body Mass Index': 25,
#   'Education': 3,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 3},
#  {'ID': 22,
#   'Reason for Absence': 27,
#   'Date': '20/04/2018',
#   'Transportation Expense': 179,
#   'Distance to Work': 26,
#   'Age': 30,
#   'Daily Work Load Average': 246.28799999999998,
#   'Body Mass Index': 19,
#   'Education': 3,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 2},
#  {'ID': 14,
#   'Reason for Absence': 28,
#   'Date': '24/04/2018',
#   'Transportation Expense': 155,
#   'Distance to Work': 12,
#   'Age': 34,
#   'Daily Work Load Average': 246.28799999999998,
#   'Body Mass Index': 25,
#   'Education': 1,
#   'Children': 2,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 4},
#  {'ID': 28,
#   'Reason for Absence': 19,
#   'Date': '26/04/2018',
#   'Transportation Expense': 225,
#   'Distance to Work': 26,
#   'Age': 28,
#   'Daily Work Load Average': 246.28799999999998,
#   'Body Mass Index': 24,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 2,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 36,
#   'Reason for Absence': 14,
#   'Date': '26/04/2018',
#   'Transportation Expense': 118,
#   'Distance to Work': 13,
#   'Age': 50,
#   'Daily Work Load Average': 246.28799999999998,
#   'Body Mass Index': 31,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 2},
#  {'ID': 22,
#   'Reason for Absence': 27,
#   'Date': '27/04/2018',
#   'Transportation Expense': 179,
#   'Distance to Work': 26,
#   'Age': 30,
#   'Daily Work Load Average': 246.28799999999998,
#   'Body Mass Index': 19,
#   'Education': 3,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 2},
#  {'ID': 1,
#   'Reason for Absence': 22,
#   'Date': '07/05/2018',
#   'Transportation Expense': 235,
#   'Distance to Work': 11,
#   'Age': 37,
#   'Daily Work Load Average': 237.65599999999998,
#   'Body Mass Index': 29,
#   'Education': 3,
#   'Children': 1,
#   'Pets': 1,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 29,
#   'Reason for Absence': 19,
#   'Date': '09/05/2018',
#   'Transportation Expense': 225,
#   'Distance to Work': 15,
#   'Age': 41,
#   'Daily Work Load Average': 237.65599999999998,
#   'Body Mass Index': 28,
#   'Education': 4,
#   'Children': 2,
#   'Pets': 2,
#   'Absenteeism Time in Hours': 3},
#  {'ID': 25,
#   'Reason for Absence': 28,
#   'Date': '09/05/2018',
#   'Transportation Expense': 235,
#   'Distance to Work': 16,
#   'Age': 32,
#   'Daily Work Load Average': 237.65599999999998,
#   'Body Mass Index': 25,
#   'Education': 3,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 2},
#  {'ID': 34,
#   'Reason for Absence': 8,
#   'Date': '09/05/2018',
#   'Transportation Expense': 118,
#   'Distance to Work': 10,
#   'Age': 37,
#   'Daily Work Load Average': 237.65599999999998,
#   'Body Mass Index': 28,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 3},
#  {'ID': 5,
#   'Reason for Absence': 26,
#   'Date': '09/05/2018',
#   'Transportation Expense': 235,
#   'Distance to Work': 20,
#   'Age': 43,
#   'Daily Work Load Average': 237.65599999999998,
#   'Body Mass Index': 38,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 22,
#   'Reason for Absence': 13,
#   'Date': '10/05/2018',
#   'Transportation Expense': 179,
#   'Distance to Work': 26,
#   'Age': 30,
#   'Daily Work Load Average': 237.65599999999998,
#   'Body Mass Index': 19,
#   'Education': 3,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 1},
#  {'ID': 15,
#   'Reason for Absence': 28,
#   'Date': '10/05/2018',
#   'Transportation Expense': 291,
#   'Distance to Work': 31,
#   'Age': 40,
#   'Daily Work Load Average': 237.65599999999998,
#   'Body Mass Index': 25,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 1,
#   'Absenteeism Time in Hours': 2},
#  {'ID': 29,
#   'Reason for Absence': 14,
#   'Date': '10/05/2018',
#   'Transportation Expense': 225,
#   'Distance to Work': 15,
#   'Age': 41,
#   'Daily Work Load Average': 237.65599999999998,
#   'Body Mass Index': 28,
#   'Education': 4,
#   'Children': 2,
#   'Pets': 2,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 26,
#   'Reason for Absence': 19,
#   'Date': '11/05/2018',
#   'Transportation Expense': 300,
#   'Distance to Work': 26,
#   'Age': 43,
#   'Daily Work Load Average': 237.65599999999998,
#   'Body Mass Index': 25,
#   'Education': 1,
#   'Children': 2,
#   'Pets': 1,
#   'Absenteeism Time in Hours': 64},
#  {'ID': 29,
#   'Reason for Absence': 22,
#   'Date': '11/05/2018',
#   'Transportation Expense': 225,
#   'Distance to Work': 15,
#   'Age': 41,
#   'Daily Work Load Average': 237.65599999999998,
#   'Body Mass Index': 28,
#   'Education': 4,
#   'Children': 2,
#   'Pets': 2,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 22,
#   'Reason for Absence': 27,
#   'Date': '11/05/2018',
#   'Transportation Expense': 179,
#   'Distance to Work': 26,
#   'Age': 30,
#   'Daily Work Load Average': 237.65599999999998,
#   'Body Mass Index': 19,
#   'Education': 3,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 2},
#  {'ID': 36,
#   'Reason for Absence': 23,
#   'Date': '14/05/2018',
#   'Transportation Expense': 118,
#   'Distance to Work': 13,
#   'Age': 50,
#   'Daily Work Load Average': 237.65599999999998,
#   'Body Mass Index': 31,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 2},
#  {'ID': 36,
#   'Reason for Absence': 5,
#   'Date': '15/05/2018',
#   'Transportation Expense': 118,
#   'Distance to Work': 13,
#   'Age': 50,
#   'Daily Work Load Average': 237.65599999999998,
#   'Body Mass Index': 31,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 3},
#  {'ID': 34,
#   'Reason for Absence': 28,
#   'Date': '15/05/2018',
#   'Transportation Expense': 118,
#   'Distance to Work': 10,
#   'Age': 37,
#   'Daily Work Load Average': 237.65599999999998,
#   'Body Mass Index': 28,
#   'Education': 1,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 1},
#  {'ID': 36,
#   'Reason for Absence': 0,
#   'Date': '15/05/2018',
#   'Transportation Expense': 118,
#   'Distance to Work': 13,
#   'Age': 50,
#   'Daily Work Load Average': 237.65599999999998,
#   'Body Mass Index': 31,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 0},
#  {'ID': 22,
#   'Reason for Absence': 27,
#   'Date': '16/05/2018',
#   'Transportation Expense': 179,
#   'Distance to Work': 26,
#   'Age': 30,
#   'Daily Work Load Average': 237.65599999999998,
#   'Body Mass Index': 19,
#   'Education': 3,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 2},
#  {'ID': 23,
#   'Reason for Absence': 0,
#   'Date': '16/05/2018',
#   'Transportation Expense': 378,
#   'Distance to Work': 49,
#   'Age': 36,
#   'Daily Work Load Average': 237.65599999999998,
#   'Body Mass Index': 21,
#   'Education': 1,
#   'Children': 2,
#   'Pets': 4,
#   'Absenteeism Time in Hours': 0},
#  {'ID': 17,
#   'Reason for Absence': 16,
#   'Date': '18/05/2018',
#   'Transportation Expense': 179,
#   'Distance to Work': 22,
#   'Age': 40,
#   'Daily Work Load Average': 237.65599999999998,
#   'Body Mass Index': 22,
#   'Education': 2,
#   'Children': 2,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 1},
#  {'ID': 14,
#   'Reason for Absence': 10,
#   'Date': '21/05/2018',
#   'Transportation Expense': 155,
#   'Distance to Work': 12,
#   'Age': 34,
#   'Daily Work Load Average': 237.65599999999998,
#   'Body Mass Index': 25,
#   'Education': 1,
#   'Children': 2,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 48},
#  {'ID': 25,
#   'Reason for Absence': 10,
#   'Date': '21/05/2018',
#   'Transportation Expense': 235,
#   'Distance to Work': 16,
#   'Age': 32,
#   'Daily Work Load Average': 237.65599999999998,
#   'Body Mass Index': 25,
#   'Education': 3,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 15,
#   'Reason for Absence': 22,
#   'Date': '23/05/2018',
#   'Transportation Expense': 291,
#   'Distance to Work': 31,
#   'Age': 40,
#   'Daily Work Load Average': 237.65599999999998,
#   'Body Mass Index': 25,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 1,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 17,
#   'Reason for Absence': 10,
#   'Date': '23/05/2018',
#   'Transportation Expense': 179,
#   'Distance to Work': 22,
#   'Age': 40,
#   'Daily Work Load Average': 237.65599999999998,
#   'Body Mass Index': 22,
#   'Education': 2,
#   'Children': 2,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 28,
#   'Reason for Absence': 6,
#   'Date': '23/05/2018',
#   'Transportation Expense': 225,
#   'Distance to Work': 26,
#   'Age': 28,
#   'Daily Work Load Average': 237.65599999999998,
#   'Body Mass Index': 24,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 2,
#   'Absenteeism Time in Hours': 3},
#  {'ID': 18,
#   'Reason for Absence': 10,
#   'Date': '24/05/2018',
#   'Transportation Expense': 330,
#   'Distance to Work': 16,
#   'Age': 28,
#   'Daily Work Load Average': 237.65599999999998,
#   'Body Mass Index': 25,
#   'Education': 2,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 8},
#  {'ID': 25,
#   'Reason for Absence': 23,
#   'Date': '24/05/2018',
#   'Transportation Expense': 235,
#   'Distance to Work': 16,
#   'Age': 32,
#   'Daily Work Load Average': 237.65599999999998,
#   'Body Mass Index': 25,
#   'Education': 3,
#   'Children': 0,
#   'Pets': 0,
#   'Absenteeism Time in Hours': 2},
#  {'ID': 15,
#   'Reason for Absence': 28,
#   'Date': '31/05/2018',
#   'Transportation Expense': 291,
#   'Distance to Work': 31,
#   'Age': 40,
#   'Daily Work Load Average': 237.65599999999998,
#   'Body Mass Index': 25,
#   'Education': 1,
#   'Children': 1,
#   'Pets': 1,
#   'Absenteeism Time in Hours': 2}]

# %%
# # connect to engine
# conn = engine.connect()

# newmeta = MetaData(bind=engine, reflect = True)
# table = Table('employees',newmeta, autoload=True)


# Session = sessionmaker(bind=engine)
# session = Session()

# conn.execute(table.insert(), list_to_write)

# session.commit()

# session.close()

# %%
conn = engine.connect()


new = data.to_sql('employees2',con = conn, method = 'multi')
session.commit()

session.close()

# %%
data.columns.values
# Out:
# array(['ID', 'Reason for Absence', 'Date', 'Transportation Expense',
#        'Distance to Work', 'Age', 'Daily Work Load Average',
#        'Body Mass Index', 'Education', 'Children', 'Pets',
#        'Absenteeism Time in Hours'], dtype=object)

# %%
# create the objects based in the df values
session = Session(bind=engine)
inserts = []
for col, j in data.iterrows():
    temp = employee(id = j['ID'], reasonForAbsence= j['Reason for Absence'],
                   date = j['Date'],
                   transportationExpense = j['Transportation Expense'],
                   distanceToWork =j['Distance to Work'],
                   age = j['Age'],
                    workload= j['Daily Work Load Average'],
                    bodyMass= j['Body Mass Index'] ,
                    education =j['Education'] ,
                    children =j['Children'] ,
                    pets =j['Pets'] ,
                    absTime =j['Absenteeism Time in Hours'] )
    inserts.append(temp)
    print (j['ID'])
# Out:
# 11
# 36
# 3
# 7
# 11
# 3
# 10
# 20
# 14
# 1
# 20
# 20
# 20
# 3
# 3
# 24
# 3
# 3
# 6
# 33
# 18
# 3
# 10
# 20
# 11
# 10
# 11
# 30
# 11
# 3
# 3
# 2
# 1
# 2
# 3
# 10
# 11
# 19
# 2
# 20
# 27
# 34
# 3
# 5
# 14
# 34
# 3
# 15
# 20
# 15
# 20
# 29
# 28
# 34
# 11
# 36
# 28
# 3
# 13
# 33
# 3
# 20
# 3
# 34
# 36
# 22
# 3
# 28
# 34
# 28
# 33
# 15
# 3
# 28
# 20
# 15
# 28
# 11
# 10
# 20
# 3
# 28
# 3
# 17
# 15
# 14
# 6
# 15
# 28
# 14
# 28
# 17
# 28
# 20
# 33
# 28
# 11
# 15
# 33
# 34
# 36
# 1
# 28
# 20
# 34
# 10
# 28
# 20
# 28
# 10
# 34
# 24
# 28
# 28
# 34
# 34
# 14
# 28
# 27
# 28
# 28
# 34
# 28
# 34
# 34
# 34
# 34
# 34
# 34
# 22
# 11
# 34
# 27
# 34
# 34
# 28
# 11
# 27
# 24
# 3
# 14
# 6
# 20
# 11
# 31
# 31
# 28
# 28
# 22
# 27
# 28
# 18
# 18
# 28
# 6
# 19
# 20
# 30
# 17
# 15
# 20
# 22
# 33
# 20
# 17
# 14
# 20
# 14
# 11
# 17
# 20
# 28
# 7
# 3
# 28
# 28
# 22
# 28
# 28
# 3
# 7
# 28
# 33
# 28
# 15
# 28
# 14
# 24
# 14
# 28
# 20
# 3
# 36
# 15
# 24
# 15
# 33
# 20
# 11
# 14
# 23
# 11
# 1
# 2
# 11
# 14
# 14
# 3
# 28
# 27
# 14
# 3
# 11
# 7
# 18
# 23
# 31
# 3
# 36
# 10
# 24
# 10
# 24
# 15
# 24
# 3
# 14
# 24
# 36
# 1
# 36
# 36
# 23
# 3
# 32
# 28
# 14
# 36
# 34
# 34
# 18
# 22
# 14
# 18
# 18
# 30
# 10
# 11
# 3
# 11
# 11
# 20
# 11
# 30
# 11
# 9
# 26
# 26
# 20
# 11
# 33
# 21
# 22
# 36
# 33
# 1
# 36
# 1
# 10
# 27
# 3
# 3
# 11
# 5
# 24
# 15
# 8
# 19
# 3
# 24
# 3
# 15
# 20
# 5
# 36
# 5
# 15
# 15
# 3
# 11
# 1
# 11
# 11
# 36
# 33
# 22
# 34
# 13
# 3
# 22
# 5
# 11
# 20
# 5
# 5
# 5
# 36
# 15
# 22
# 36
# 10
# 20
# 15
# 30
# 22
# 22
# 36
# 34
# 33
# 3
# 20
# 15
# 23
# 14
# 5
# 18
# 1
# 34
# 1
# 3
# 24
# 15
# 24
# 3
# 20
# 20
# 23
# 7
# 3
# 28
# 3
# 3
# 1
# 36
# 20
# 24
# 3
# 3
# 22
# 34
# 1
# 3
# 5
# 1
# 20
# 30
# 3
# 11
# 28
# 34
# 14
# 1
# 14
# 11
# 15
# 5
# 36
# 3
# 3
# 34
# 3
# 28
# 11
# 20
# 3
# 3
# 3
# 3
# 24
# 3
# 6
# 3
# 24
# 15
# 30
# 3
# 3
# 24
# 3
# 3
# 34
# 24
# 24
# 20
# 3
# 1
# 17
# 23
# 3
# 10
# 13
# 1
# 36
# 36
# 36
# 1
# 24
# 36
# 3
# 11
# 20
# 24
# 3
# 20
# 18
# 13
# 33
# 18
# 3
# 36
# 36
# 26
# 20
# 3
# 34
# 5
# 33
# 13
# 22
# 3
# 10
# 20
# 17
# 17
# 9
# 28
# 18
# 22
# 34
# 1
# 22
# 34
# 3
# 34
# 28
# 20
# 3
# 15
# 3
# 24
# 3
# 5
# 3
# 28
# 36
# 3
# 22
# 24
# 18
# 1
# 22
# 28
# 20
# 21
# 18
# 34
# 20
# 34
# 26
# 2
# 24
# 28
# 3
# 36
# 10
# 11
# 5
# 24
# 15
# 7
# 3
# 17
# 24
# 34
# 11
# 5
# 15
# 3
# 17
# 18
# 1
# 24
# 34
# 15
# 20
# 24
# 24
# 34
# 14
# 15
# 22
# 33
# 3
# 28
# 22
# 13
# 10
# 32
# 25
# 24
# 32
# 15
# 34
# 32
# 15
# 28
# 13
# 13
# 28
# 13
# 3
# 9
# 15
# 13
# 28
# 13
# 28
# 6
# 25
# 33
# 28
# 28
# 3
# 34
# 18
# 3
# 34
# 11
# 25
# 28
# 10
# 15
# 34
# 28
# 3
# 34
# 34
# 28
# 15
# 11
# 33
# 5
# 28
# 13
# 10
# 3
# 15
# 28
# 22
# 28
# 28
# 10
# 17
# 5
# 12
# 22
# 28
# 28
# 28
# 14
# 22
# 22
# 17
# 17
# 22
# 17
# 32
# 17
# 22
# 14
# 22
# 3
# 11
# 3
# 3
# 3
# 28
# 33
# 3
# 28
# 3
# 22
# 29
# 3
# 12
# 3
# 28
# 3
# 3
# 28
# 22
# 17
# 3
# 12
# 22
# 3
# 3
# 3
# 14
# 25
# 3
# 28
# 3
# 33
# 28
# 3
# 3
# 25
# 3
# 33
# 9
# 33
# 9
# 3
# 28
# 3
# 28
# 22
# 25
# 10
# 3
# 3
# 3
# 22
# 3
# 33
# 3
# 28
# 3
# 11
# 9
# 3
# 33
# 3
# 22
# 3
# 3
# 16
# 14
# 3
# 3
# 22
# 11
# 13
# 28
# 34
# 10
# 33
# 6
# 22
# 13
# 17
# 36
# 10
# 34
# 1
# 22
# 28
# 25
# 22
# 14
# 28
# 36
# 22
# 1
# 29
# 25
# 34
# 5
# 22
# 15
# 29
# 26
# 29
# 22
# 36
# 36
# 34
# 36
# 22
# 23
# 17
# 14
# 25
# 15
# 17
# 28
# 18
# 25
# 15

# %%
# verify if objects have been appended correctly to the list
print(inserts)
# Out:
# [<__main__.employee object at 0x000002B442D72780>, <__main__.employee object at 0x000002B442BD0C50>, <__main__.employee object at 0x000002B442BD04A8>, <__main__.employee object at 0x000002B442BD06A0>, <__main__.employee object at 0x000002B442BD0710>, <__main__.employee object at 0x000002B442BD0F60>, <__main__.employee object at 0x000002B44227E0F0>, <__main__.employee object at 0x000002B44227E080>, <__main__.employee object at 0x000002B44227E400>, <__main__.employee object at 0x000002B44227E6D8>, <__main__.employee object at 0x000002B44227EBE0>, <__main__.employee object at 0x000002B44227EB70>, <__main__.employee object at 0x000002B44227E278>, <__main__.employee object at 0x000002B4427B24E0>, <__main__.employee object at 0x000002B4427B2EF0>, <__main__.employee object at 0x000002B4427B2908>, <__main__.employee object at 0x000002B441DF6F28>, <__main__.employee object at 0x000002B4427B2D30>, <__main__.employee object at 0x000002B4427B2F60>, <__main__.employee object at 0x000002B44227EDD8>, <__main__.employee object at 0x000002B442D707B8>, <__main__.employee object at 0x000002B442D706A0>, <__main__.employee object at 0x000002B442D70E10>, <__main__.employee object at 0x000002B442D70E48>, <__main__.employee object at 0x000002B442D70B38>, <__main__.employee object at 0x000002B4427F0E48>, <__main__.employee object at 0x000002B4427F0198>, <__main__.employee object at 0x000002B4427F0F28>, <__main__.employee object at 0x000002B4427F0DA0>, <__main__.employee object at 0x000002B4427F0B38>, <__main__.employee object at 0x000002B4427F0400>, <__main__.employee object at 0x000002B4427F0128>, <__main__.employee object at 0x000002B4427B2550>, <__main__.employee object at 0x000002B442B29D68>, <__main__.employee object at 0x000002B442B29E10>, <__main__.employee object at 0x000002B442B29DD8>, <__main__.employee object at 0x000002B442B29240>, <__main__.employee object at 0x000002B442B29048>, <__main__.employee object at 0x000002B44280BF60>, <__main__.employee object at 0x000002B44280BE10>, <__main__.employee object at 0x000002B44280BCF8>, <__main__.employee object at 0x000002B44280BB38>, <__main__.employee object at 0x000002B44280B898>, <__main__.employee object at 0x000002B44280B470>, <__main__.employee object at 0x000002B44280B128>, <__main__.employee object at 0x000002B44280B278>, <__main__.employee object at 0x000002B4429936A0>, <__main__.employee object at 0x000002B442993EB8>, <__main__.employee object at 0x000002B442993C18>, <__main__.employee object at 0x000002B442993128>, <__main__.employee object at 0x000002B442993908>, <__main__.employee object at 0x000002B442993240>, <__main__.employee object at 0x000002B44226B390>, <__main__.employee object at 0x000002B44226B550>, <__main__.employee object at 0x000002B44226B780>, <__main__.employee object at 0x000002B44226BAC8>, <__main__.employee object at 0x000002B44226BF98>, <__main__.employee object at 0x000002B44226B9B0>, <__main__.employee object at 0x000002B4427907B8>, <__main__.employee object at 0x000002B4427905F8>, <__main__.employee object at 0x000002B442790E80>, <__main__.employee object at 0x000002B4427909E8>, <__main__.employee object at 0x000002B442790748>, <__main__.employee object at 0x000002B442790550>, <__main__.employee object at 0x000002B442790358>, <__main__.employee object at 0x000002B442790198>, <__main__.employee object at 0x000002B4429D7EF0>, <__main__.employee object at 0x000002B4429D7860>, <__main__.employee object at 0x000002B4429D75F8>, <__main__.employee object at 0x000002B4429D7BA8>, <__main__.employee object at 0x000002B442BFBCF8>, <__main__.employee object at 0x000002B442BFB860>, <__main__.employee object at 0x000002B442BFB8D0>, <__main__.employee object at 0x000002B442BFB320>, <__main__.employee object at 0x000002B442BFBC88>, <__main__.employee object at 0x000002B442BFBEB8>, <__main__.employee object at 0x000002B442BBF518>, <__main__.employee object at 0x000002B442BBFB00>, <__main__.employee object at 0x000002B442BBF0F0>, <__main__.employee object at 0x000002B442BBF6D8>, ...

# %%
# isenrting each value to the DB table and closing the session
for i in inserts:
    session.add(i)
    
session.commit()
session.close()
# Out:
# C:\Users\luico\.conda\envs\PythonData\lib\site-packages\sqlalchemy\orm\session.py:1895: SAWarning: Identity map already had an identity for (<class '__main__.employee'>, (3,), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   "within the flush?" % (instance_key,)
# C:\Users\luico\.conda\envs\PythonData\lib\site-packages\sqlalchemy\orm\session.py:1895: SAWarning: Identity map already had an identity for (<class '__main__.employee'>, (34,), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   "within the flush?" % (instance_key,)
# C:\Users\luico\.conda\envs\PythonData\lib\site-packages\sqlalchemy\orm\session.py:1895: SAWarning: Identity map already had an identity for (<class '__main__.employee'>, (22,), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   "within the flush?" % (instance_key,)
# C:\Users\luico\.conda\envs\PythonData\lib\site-packages\sqlalchemy\orm\session.py:1895: SAWarning: Identity map already had an identity for (<class '__main__.employee'>, (11,), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   "within the flush?" % (instance_key,)
# C:\Users\luico\.conda\envs\PythonData\lib\site-packages\sqlalchemy\orm\session.py:1895: SAWarning: Identity map already had an identity for (<class '__main__.employee'>, (28,), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   "within the flush?" % (instance_key,)
# C:\Users\luico\.conda\envs\PythonData\lib\site-packages\sqlalchemy\orm\session.py:1895: SAWarning: Identity map already had an identity for (<class '__main__.employee'>, (20,), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   "within the flush?" % (instance_key,)
# C:\Users\luico\.conda\envs\PythonData\lib\site-packages\sqlalchemy\orm\session.py:1895: SAWarning: Identity map already had an identity for (<class '__main__.employee'>, (5,), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   "within the flush?" % (instance_key,)
# C:\Users\luico\.conda\envs\PythonData\lib\site-packages\sqlalchemy\orm\session.py:1895: SAWarning: Identity map already had an identity for (<class '__main__.employee'>, (33,), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   "within the flush?" % (instance_key,)
# C:\Users\luico\.conda\envs\PythonData\lib\site-packages\sqlalchemy\orm\session.py:1895: SAWarning: Identity map already had an identity for (<class '__main__.employee'>, (36,), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   "within the flush?" % (instance_key,)
# C:\Users\luico\.conda\envs\PythonData\lib\site-packages\sqlalchemy\orm\session.py:1895: SAWarning: Identity map already had an identity for (<class '__main__.employee'>, (6,), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   "within the flush?" % (instance_key,)
# C:\Users\luico\.conda\envs\PythonData\lib\site-packages\sqlalchemy\orm\session.py:1895: SAWarning: Identity map already had an identity for (<class '__main__.employee'>, (13,), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   "within the flush?" % (instance_key,)
# C:\Users\luico\.conda\envs\PythonData\lib\site-packages\sqlalchemy\orm\session.py:1895: SAWarning: Identity map already had an identity for (<class '__main__.employee'>, (10,), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   "within the flush?" % (instance_key,)
# C:\Users\luico\.conda\envs\PythonData\lib\site-packages\sqlalchemy\orm\session.py:1895: SAWarning: Identity map already had an identity for (<class '__main__.employee'>, (24,), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   "within the flush?" % (instance_key,)
# C:\Users\luico\.conda\envs\PythonData\lib\site-packages\sqlalchemy\orm\session.py:1895: SAWarning: Identity map already had an identity for (<class '__main__.employee'>, (15,), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   "within the flush?" % (instance_key,)
# C:\Users\luico\.conda\envs\PythonData\lib\site-packages\sqlalchemy\orm\session.py:1895: SAWarning: Identity map already had an identity for (<class '__main__.employee'>, (14,), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   "within the flush?" % (instance_key,)
# C:\Users\luico\.conda\envs\PythonData\lib\site-packages\sqlalchemy\orm\session.py:1895: SAWarning: Identity map already had an identity for (<class '__main__.employee'>, (30,), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   "within the flush?" % (instance_key,)
# C:\Users\luico\.conda\envs\PythonData\lib\site-packages\sqlalchemy\orm\session.py:1895: SAWarning: Identity map already had an identity for (<class '__main__.employee'>, (1,), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   "within the flush?" % (instance_key,)
# C:\Users\luico\.conda\envs\PythonData\lib\site-packages\sqlalchemy\orm\session.py:1895: SAWarning: Identity map already had an identity for (<class '__main__.employee'>, (9,), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   "within the flush?" % (instance_key,)
# C:\Users\luico\.conda\envs\PythonData\lib\site-packages\sqlalchemy\orm\session.py:1895: SAWarning: Identity map already had an identity for (<class '__main__.employee'>, (26,), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   "within the flush?" % (instance_key,)
# C:\Users\luico\.conda\envs\PythonData\lib\site-packages\sqlalchemy\orm\session.py:1895: SAWarning: Identity map already had an identity for (<class '__main__.employee'>, (2,), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   "within the flush?" % (instance_key,)
# C:\Users\luico\.conda\envs\PythonData\lib\site-packages\sqlalchemy\orm\session.py:1895: SAWarning: Identity map already had an identity for (<class '__main__.employee'>, (27,), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   "within the flush?" % (instance_key,)
# C:\Users\luico\.conda\envs\PythonData\lib\site-packages\sqlalchemy\orm\session.py:1895: SAWarning: Identity map already had an identity for (<class '__main__.employee'>, (18,), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   "within the flush?" % (instance_key,)
# C:\Users\luico\.conda\envs\PythonData\lib\site-packages\sqlalchemy\orm\session.py:1895: SAWarning: Identity map already had an identity for (<class '__main__.employee'>, (25,), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   "within the flush?" % (instance_key,)
# C:\Users\luico\.conda\envs\PythonData\lib\site-packages\sqlalchemy\orm\session.py:1895: SAWarning: Identity map already had an identity for (<class '__main__.employee'>, (29,), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   "within the flush?" % (instance_key,)
# C:\Users\luico\.conda\envs\PythonData\lib\site-packages\sqlalchemy\orm\session.py:1895: SAWarning: Identity map already had an identity for (<class '__main__.employee'>, (17,), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   "within the flush?" % (instance_key,)
# C:\Users\luico\.conda\envs\PythonData\lib\site-packages\sqlalchemy\orm\session.py:1895: SAWarning: Identity map already had an identity for (<class '__main__.employee'>, (12,), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   "within the flush?" % (instance_key,)
# C:\Users\luico\.conda\envs\PythonData\lib\site-packages\sqlalchemy\orm\session.py:1895: SAWarning: Identity map already had an identity for (<class '__main__.employee'>, (21,), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   "within the flush?" % (instance_key,)
# C:\Users\luico\.conda\envs\PythonData\lib\site-packages\sqlalchemy\orm\session.py:1895: SAWarning: Identity map already had an identity for (<class '__main__.employee'>, (31,), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   "within the flush?" % (instance_key,)
# C:\Users\luico\.conda\envs\PythonData\lib\site-packages\sqlalchemy\orm\session.py:1895: SAWarning: Identity map already had an identity for (<class '__main__.employee'>, (19,), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   "within the flush?" % (instance_key,)
# C:\Users\luico\.conda\envs\PythonData\lib\site-packages\sqlalchemy\orm\session.py:1895: SAWarning: Identity map already had an identity for (<class '__main__.employee'>, (23,), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   "within the flush?" % (instance_key,)
# C:\Users\luico\.conda\envs\PythonData\lib\site-packages\sqlalchemy\orm\session.py:1895: SAWarning: Identity map already had an identity for (<class '__main__.employee'>, (32,), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   "within the flush?" % (instance_key,)
# C:\Users\luico\.conda\envs\PythonData\lib\site-packages\sqlalchemy\orm\session.py:1895: SAWarning: Identity map already had an identity for (<class '__main__.employee'>, (7,), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   "within the flush?" % (instance_key,)
